# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
from IPython.core.pylabtools import figsize

print("Hello World!")
# Out:
# Hello World!

# %%
import pandas as pd

# %%
sales = pd.read_csv('data/sales.csv')

# %%
sales
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales.isnull().sum
# Out:
# <bound method DataFrame.sum of          Date    Day  Month   Year  Customer_Age  Age_Group  Customer_Gender  \
# 0       False  False  False  False         False      False            False
# 1       False  False  False  False         False      False            False
# 2       False  False  False  False         False      False            False
# 3       False  False  False  False         False      False            False
# 4       False  False  False  False         False      False            False
# ...       ...    ...    ...    ...           ...        ...              ...
# 113031  False  False  False  False         False      False            False
# 113032  False  False  False  False         False      False            False
# 113033  False  False  False  False         False      False            False
# 113034  False  False  False  False         False      False            False
# 113035  False  False  False  False         False      False            False
#
# ...

# %% [markdown]
# # Class proportion

# %%
import seaborn as sns
sns.countplot(x='Age_Group', data=sales)
# Out:
# <Axes: xlabel='Age_Group', ylabel='count'>

# %%
sns.countplot(x='Customer_Gender', data=sales)
# Out:
# <Axes: xlabel='Customer_Gender', ylabel='count'>

# %%
sns.countplot(x='Product_Category', data=sales)
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
sns.countplot(x='Year', data=sales)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %% [markdown]
# # Outliers

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='Order_Quantity', data=sales)


plt.title('Order Quantity boxplot')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='Customer_Age', data=sales)


plt.title('Customer Age boxplot')
plt.show()

# %% [markdown]
# # Correlation

# %%
numeric_sales = sales.select_dtypes(include='number')
correlation_matrix = numeric_sales.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # Drop

# %%
sales_dropped_numeric = sales.drop(columns=['Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue'])

# %%
sales_dropped_numeric
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales_dropped = sales_dropped_numeric.drop(columns=['Customer_Age'])

# %%
sales_dropped
# Out:
#               Date  Day     Month  Year       Age_Group Customer_Gender  \
# 0       2013-11-26   26  November  2013     Youth (<25)               M
# 1       2015-11-26   26  November  2015     Youth (<25)               M
# 2       2014-03-23   23     March  2014  Adults (35-64)               M
# 3       2016-03-23   23     March  2016  Adults (35-64)               M
# 4       2014-05-15   15       May  2014  Adults (35-64)               F
# ...            ...  ...       ...   ...             ...             ...
# 113031  2016-04-12   12     April  2016  Adults (35-64)               M
# 113032  2014-04-02    2     April  2014     Youth (<25)               M
# 113033  2016-04-02    2     April  2016     Youth (<25)               M
# 113034  2014-03-04    4     March  2014  Adults (35-64)               F
# 113035  2016-03-04    4     March  2016  Adults (35-64)               F
#
#                Country             State Product_Category Sub_Category  \
# ...
